# %% [markdown]
# <a href="https://colab.research.google.com/github/Laxmi-Prajapati/Synapse_ML_Tasks/blob/main/Synapse_Task2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Synapse - Task 2
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Run the following cell to import your google drive.

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# Run the following cell to import the required libraries.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Task 2.1

# %% [markdown]
# For aspiring data scientists and machine learning enthusiasts, it is vital that they understand the coding environment. We normally use a jupyter notebook for most of our programming. To understand its importance, lets perform a small exercise.
#
# We are given 2 datasets, they have data of certain students from 2 different branches and their respective divisions.
#
# Download the datasets from the links given below -
#
# Task2p1_0 - https://drive.google.com/file/d/1sCGCErnf2iC_qKUHcGLrt2O2HwuiwZYD/view?usp=sharing
#
# Task2p1_1 - https://drive.google.com/file/d/1Kb_TcAEfsUGi-KPZpsh8pXBaxfs4AsHh/view?usp=sharing
#
# Create a folder named 'Synapse' in your google drive and upload the datasets 'Task2p1_0' and 'Task2p1_1' there.

# %% [markdown]
# ###Python Script

# %%
data = pd.read_csv("/content/gdrive/MyDrive/Synapse/Task2p1_0.csv")
data
data = pd.read_csv("/content/gdrive/MyDrive/Synapse/Task2p1_1.csv")
data
# Out:
#   Student  Division
# 0        A        b
# 1        B        b
# 2        C        a
# 3        D        c
# 4        E        b
# 5        F        c
# 6        G        a

# %% [markdown]
# ###Jupyter Notebook

# %%
data = pd.read_csv("/content/gdrive/MyDrive/Synapse/Task2p1_0.csv")

# %%
data
# Out:
#   Student  Division
# 0        A        a
# 1        B        a
# 2        C        c
# 3        D        b
# 4        E        c
# 5        F        a
# 6        G        c

# %%
data = pd.read_csv("/content/gdrive/MyDrive/Synapse/Task2p1_1.csv")

# %%
data
# Out:
#   Student  Division
# 0        A        b
# 1        B        b
# 2        C        a
# 3        D        c
# 4        E        b
# 5        F        c
# 6        G        a

# %% [markdown]
# We are given a tabular dataset that consists of listings of all the movies and tv shows available on Netflix, along with details such as - cast, directors, ratings, release year, duration, etc.
#
# Download the dataset from the link given below -
#
# https://drive.google.com/file/d/1VGTLXJX_W4Faamfjp5VPM6Amqxw4GMDB/view?usp=drive_link
#
# Create a folder named 'Synapse' in your drive and upload the .csv file there.

# %% [markdown]
# Run the following cell, once the steps mentioned above are completed.

# %%
df = pd.read_csv("/content/gdrive/MyDrive/Synapse/netflix_titles.csv")
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                   NaN            NaN
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
# ...                                                 ...            ...
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#               date_added  release_year rating   duration  \
# 0     September 25, 2021          2020  PG-13     90 min
# 1     September 24, 2021          2021  TV-MA  2 Seasons
# 2     September 24, 2021          2021  TV-MA   1 Season
# 3     September 24, 2021          2021  TV-MA   1 Season
# 4     September 24, 2021          2021  TV-MA  2 Seasons
# ...                  ...           ...    ...        ...
# 8802   November 20, 2019          2007      R    158 min
# 8803        July 1, 2019          2018  TV-Y7  2 Seasons
# 8804    November 1, 2019          2009      R     88 min
# 8805    January 11, 2020          2006     PG     88 min
# 8806       March 2, 2019          2015  TV-14    111 min
#
#                                               listed_in  \
# 0                                         Documentaries
# 1       International TV Shows, TV Dramas, TV Mysteries
# 2     Crime TV Shows, International TV Shows, TV Act...
# 3                                Docuseries, Reality TV
# 4     International TV Shows, Romantic TV Shows, TV ...
# ...                                                 ...
# 8802                     Cult Movies, Dramas, Thrillers
# 8803             Kids' TV, Korean TV Shows, TV Comedies
# 8804                            Comedies, Horror Movies
# 8805                 Children & Family Movies, Comedies
# 8806     Dramas, International Movies, Music & Musicals
#
#                                             description
# 0     As her father nears the end of his life, filmm...
# 1     After crossing paths at a party, a Cape Town t...
# 2     To protect his family from a powerful drug lor...
# 3     Feuds, flirtations and toilet talk go down amo...
# 4     In a city of coaching centers known to train I...
# ...                                                 ...
# 8802  A political cartoonist, a crime reporter and a...
# 8803  While living alone in a spooky town, a young g...
# 8804  Looking to survive in a world taken over by zo...
# 8805  Dragged from civilian life, a former superhero...
# 8806  A scrappy but poor boy worms his way into a ty...
#
# [8807 rows x 12 columns]

# %% [markdown]
# The dataset contains 8807 rows

# %% [markdown]
# ## Task 2.1 - Preprocessing

# %% [markdown]
# Display the first 10 elements of the dataframe.

# %%
df.head(10)
# Out:
#   show_id     type                          title             director  \
# 0      s8    Movie                        Sankofa         Haile Gerima
# 1      s9  TV Show  The Great British Baking Show      Andy Devonshire
# 2     s10    Movie                   The Starling       Theodore Melfi
# 3     s13    Movie                   Je Suis Karl  Christian Schwochow
# 4     s25    Movie                          Jeans           S. Shankar
# 5     s28    Movie                      Grown Ups         Dennis Dugan
# 6     s29    Movie                     Dark Skies        Scott Stewart
# 7     s30    Movie                       Paranoia       Robert Luketic
# 8     s39    Movie            Birth of the Dragon         George Nolfi
# 9     s42    Movie                           Jaws     Steven Spielberg
#
#                                                 cast  \
# 0  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 1  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# 2  Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 3  Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
# 4  Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...
# 5  Adam Sandler, Kevin James, Chris Rock, David S...
# 6  Keri Russell, Josh Hamilton, J.K. Simmons, Dak...
# 7  Liam Hemsworth, Gary Oldman, Amber Heard, Harr...
# 8  Billy Magnussen, Ron Yuan, Qu Jingjing, Terry ...
# 9  Roy Scheider, Robert Shaw, Richard Dreyfuss, L...
#
#                                              country          date_added  \
# 0  United States, Ghana, Burkina Faso, United Kin...  September 24, 2021
# 1                                     United Kingdom  September 24, 2021
# 2                                      United States  September 24, 2021
# 3                            Germany, Czech Republic  September 23, 2021
# 4                                              India  September 21, 2021
# 5                                      United States  September 20, 2021
# 6                                      United States  September 19, 2021
# 7                       United States, India, France  September 19, 2021
# 8                       China, Canada, United States  September 16, 2021
# 9                                      United States  September 16, 2021
#
#    release_year rating   duration  \
# 0          1993  TV-MA    125 min
# 1          2021  TV-14  9 Seasons
# 2          2021  PG-13    104 min
# 3          2021  TV-MA    127 min
# 4          1998  TV-14    166 min
# 5          2010  PG-13    103 min
# 6          2013  PG-13     97 min
# 7          2013  PG-13    106 min
# 8          2017  PG-13     96 min
# 9          1975     PG    124 min
#
#                                           listed_in  \
# 0  Dramas, Independent Movies, International Movies
# 1                      British TV Shows, Reality TV
# 2                                  Comedies, Dramas
# 3                      Dramas, International Movies
# 4   Comedies, International Movies, Romantic Movies
# 5                                          Comedies
# 6                   Horror Movies, Sci-Fi & Fantasy
# 7                                         Thrillers
# 8                        Action & Adventure, Dramas
# 9        Action & Adventure, Classic Movies, Dramas
#
#                                          description
# 0  On a photo shoot in Ghana, an American model s...
# 1  A talented batch of amateur bakers face off in...
# 2  A woman adjusting to life after a loss contend...
# 3  After most of her family is murdered in a terr...
# 4  When the father of the man she loves insists t...
# 5  Mourning the loss of their beloved junior high...
# 6  A family’s idyllic suburban life shatters when...
# 7  Blackmailed by his company's CEO, a low-level ...
# 8  A young Bruce Lee angers kung fu traditionalis...
# 9  When an insatiable great white shark terrorize...

# %% [markdown]
# It is very important to clean the dataset before it is used. For this, remove all the rows from the dataset that have NaN values.
#
# Once the rows are dropped, you will see that there is discontinuity in the dataframe. Thus, don't forget to reset the indices.
#
# Failing to do so, will result in errors in the following cells.

# %%
df.dropna(inplace = True)
df.reset_index(drop = True, inplace = True)
print("No.of rows:", df.shape[0])
# Out:
# No.of rows: 5332

# %% [markdown]
# You should have 5332 rows after cleaning

# %% [markdown]
# ## Task 2.2 - Operations

# %% [markdown]
# Write a code to give me the number of rows that have the release_year as 2021 and type as Movie.

# %%
# Your output will be 146, if correct
desired_release_year = 2021
desired_type = "Movie"

mask = (df['release_year'] == desired_release_year) & (df['type'] == desired_type)
required_df = df[mask]

required_df.reset_index(drop = True, inplace = True)
required_df
# Out:
#     show_id   type                          title               director  \
# 0       s10  Movie                   The Starling         Theodore Melfi
# 1       s13  Movie                   Je Suis Karl    Christian Schwochow
# 2       s82  Movie                           Kate  Cedric Nicolas-Troyan
# 3      s191  Movie                     Thimmarusu      Sharan Koppisetty
# 4      s232  Movie                  The Water Man          David Oyelowo
# ..      ...    ...                            ...                    ...
# 141   s1411  Movie  Tribhanga - Tedhi Medhi Crazy         Renuka Shahane
# 142   s1412  Movie    What Would Sophia Loren Do?          Ross Kauffman
# 143   s1413  Movie                       Wish You            Sung Do-jun
# 144   s1425  Movie                       Charming           Ross Venokur
# 145   s1469  Movie      What Happened to Mr. Cha?           Kim Dong-kyu
#
#                                                   cast  \
# 0    Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 1    Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
# 2    Mary Elizabeth Winstead, Jun Kunimura, Woody H...
# 3               Satya Dev, Priyanka Jawalkar, Brahmaji
# 4    David Oyelowo, Rosario Dawson, Lonnie Chavis, ...
# ..                                                 ...
# 141  Kajol, Tanvi Azmi, Mithila Palkar, Kunaal Roy ...
# 142        Nancy "Vincenza Careri" Kulik, Sophia Loren
# 143                     Kang In-soo, Lee Sang, Soo-bin
# 144  Wilmer Valderrama, Demi Lovato, Sia, Nia Varda...
# 145           Cha In-pyo, Cho Dal-hwan, Song Jae-ryong
#
#                                    country          date_added  release_year  \
# 0                            United States  September 24, 2021          2021
# 1                  Germany, Czech Republic  September 23, 2021          2021
# 2                            United States  September 10, 2021          2021
# 3                                    India     August 28, 2021          2021
# 4                            United States     August 25, 2021          2021
# ..                                     ...                 ...           ...
# 141                                  India    January 15, 2021          2021
# 142                          United States    January 15, 2021          2021
# 143                            South Korea    January 15, 2021          2021
# 144  Canada, United States, Cayman Islands     January 8, 2021          2021
# 145                            South Korea     January 1, 2021          2021
#
#     rating duration                                   listed_in  \
# 0    PG-13  104 min                            Comedies, Dramas
# 1    TV-MA  127 min                Dramas, International Movies
# 2        R  106 min                          Action & Adventure
# 3    TV-14  125 min                Dramas, International Movies
# 4       PG   92 min            Children & Family Movies, Dramas
# ..     ...      ...                                         ...
# 141  TV-MA   96 min                Dramas, International Movies
# 142  TV-14   32 min                               Documentaries
# 143  TV-PG  102 min  Dramas, International Movies, LGBTQ Movies
# 144  TV-Y7   85 min          Children & Family Movies, Comedies
# 145  TV-MA  102 min              Comedies, International Movies
#
#                                            description
# 0    A woman adjusting to life after a loss contend...
# 1    After most of her family is murdered in a terr...
# 2    Slipped a fatal poison on her final job, a rut...
# 3    Eight years after a young man is framed for mu...
# 4    Desperate to save his ailing mother, 11-year-o...
# ..                                                 ...
# 141  When her estranged mother falls into a coma, a...
# 142  In this delightful short documentary, an Itali...
# 143  Singing and dreaming together, a talented sing...
# 144  On the eve of his 21st birthday, an adored pri...
# 145  With the peak of his career long behind him, a...
#
# [146 rows x 12 columns]

# %% [markdown]
# Write a code to create a list of all the movies that have the word 'Avengers' in it.

# %%
# Your output will contain 2 movies, if correct
mask = df['title'].str.contains('Avengers')
required_df = df[mask]

required_df
# Out:
#      show_id   type                                            title  \
# 2934   s5341  Movie  LEGO Marvel Super Heroes: Avengers Reassembled!
# 3500   s6201  Movie                           Avengers: Infinity War
#
#                       director  \
# 2934             Rob Silvestri
# 3500  Anthony Russo, Joe Russo
#
#                                                    cast        country  \
# 2934  Laura Bailey, Troy Baker, Eric Bauza, Ben Disk...  United States
# 3500  Robert Downey Jr., Josh Brolin, Mark Ruffalo, ...  United States
#
#              date_added  release_year rating duration  \
# 2934     August 6, 2017          2015  TV-Y7   22 min
# 3500  December 25, 2018          2018  PG-13  150 min
#
#                                  listed_in  \
# 2934              Children & Family Movies
# 3500  Action & Adventure, Sci-Fi & Fantasy
#
#                                             description
# 2934  When Ultron seizes control of Iron Man's armor...
# 3500  Superheroes amass to stop intergalactic sociop...

# %% [markdown]
# Display the number of Movies/TV shows per country.

# %%
req_df = df['country'].value_counts()
req_df = pd.DataFrame(req_df)
req = df.groupby(['country','type'])
req_df = req_df.reset_index().rename(columns = {'index': 'country', 'country' : 'count'})

req_df
# Out:
#                                           country  count
# 0                                   United States   1846
# 1                                           India    875
# 2                                  United Kingdom    183
# 3                                          Canada    107
# 4                                           Spain     91
# ..                                            ...    ...
# 599                            Uruguay, Guatemala      1
# 600                    Romania, Bulgaria, Hungary      1
# 601                    Philippines, United States      1
# 602  India, United Kingdom, Canada, United States      1
# 603                  United Arab Emirates, Jordan      1
#
# [604 rows x 2 columns]

# %%
expanded_data = []

for index, row in df.iterrows():
  countries = [country.strip() for country in row['country'].strip().split(',')]
  for country in countries:
    expanded_data.append({'country': country, 'type': row['type']})

expanded_df = pd.DataFrame(expanded_data)

grouped_df = expanded_df.groupby(['country','type']).size().reset_index().rename(columns= {0: 'count'})


print(grouped_df)
# Out:
#           country   type  count
# 0                  Movie      4
# 1     Afghanistan  Movie      1
# 2         Albania  Movie      1
# 3         Algeria  Movie      3
# 4          Angola  Movie      1
# ..            ...    ...    ...
# 139  Vatican City  Movie      1
# 140     Venezuela  Movie      2
# 141       Vietnam  Movie      7
# 142  West Germany  Movie      2
# 143      Zimbabwe  Movie      1
#
# [144 rows x 3 columns]

# %% [markdown]
# Display a new dataframe, that contains only those movies that are present in the Top 5 countries.
#
# (Don't forget to reset the indices again)

# %%
7# The length of new dataframe will be 3102, if correct
top = req_df.head(5)
req2 = pd.DataFrame()

for cntry in top['country']:
  req2 = req2.append(df[(df['country'] == cntry)])

req2['title'].unique()
req2.reset_index(drop = True, inplace = True)
req2
# Out:
# <ipython-input-91-fbb0d6d71fa7>:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   req2 = req2.append(df[(df['country'] == cntry)])
# <ipython-input-91-fbb0d6d71fa7>:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   req2 = req2.append(df[(df['country'] == cntry)])
# <ipython-input-91-fbb0d6d71fa7>:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   req2 = req2.append(df[(df['country'] == cntry)])
# <ipython-input-91-fbb0d6d71fa7>:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   req2 = req2.append(df[(df['country'] == cntry)])
# <ipython-input-91-fbb0d6d71fa7>:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   req2 = req2.append(df[(df['country'] == cntry)])
#      show_id   type                   title                  director  \
# 0        s10  Movie            The Starling            Theodore Melfi
# 1        s28  Movie               Grown Ups              Dennis Dugan
# 2        s29  Movie              Dark Skies             Scott Stewart
# 3        s42  Movie                    Jaws          Steven Spielberg
# 4        s43  Movie                  Jaws 2            Jeannot Szwarc
# ...      ...    ...                     ...                       ...
# 3097   s7642  Movie              Off Course          Nacho G. Velilla
# 3098   s7701  Movie  Palm Trees in the Snow  Fernando González Molina
# 3099   s8078  Movie                Spy Time       Javier Ruiz Caldera
# 3100   s8344  Movie      The Heroes of Evil             Zoe Berriatúa
# 3101   s8706  Movie         We Need to Talk             David Serrano
#
#                                                    cast        country  \
# 0     Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...  United States
# 1     Adam Sandler, Kevin James, Chris Rock, David S...  United States
# 2     Keri Russell, Josh Hamilton, J.K. Simmons, Dak...  United States
# 3     Roy Scheider, Robert Shaw, Richard Dreyfuss, L...  United States
# 4     Roy Scheider, Lorraine Gary, Murray Hamilton, ...  United States
# ...                                                 ...            ...
# 3097  Yon González, Julián López, Blanca Suárez, Mal...          Spain
# 3098  Mario Casas, Adriana Ugarte, Macarena García, ...          Spain
# 3099  Imanol Arias, Quim Gutiérrez, Alexandra Jiméne...          Spain
# 3100  Emilio Palacios, Jorge Clemente, Beatriz Medin...          Spain
# 3101  Hugo Silva, Michelle Jenner, Ernesto Sevilla, ...          Spain
#
#               date_added  release_year rating duration  \
# 0     September 24, 2021          2021  PG-13  104 min
# 1     September 20, 2021          2010  PG-13  103 min
# 2     September 19, 2021          2013  PG-13   97 min
# 3     September 16, 2021          1975     PG  124 min
# 4     September 16, 2021          1978     PG  116 min
# ...                  ...           ...    ...      ...
# 3097   September 1, 2016          2015  TV-MA  107 min
# 3098         May 1, 2016          2015  TV-MA  163 min
# 3099        June 1, 2016          2015  TV-MA   93 min
# 3100        June 1, 2016          2015  TV-MA   99 min
# 3101   September 1, 2016          2016  TV-MA   91 min
#
#                                               listed_in  \
# 0                                      Comedies, Dramas
# 1                                              Comedies
# 2                       Horror Movies, Sci-Fi & Fantasy
# 3            Action & Adventure, Classic Movies, Dramas
# 4                      Dramas, Horror Movies, Thrillers
# ...                                                 ...
# 3097                     Comedies, International Movies
# 3098      Dramas, International Movies, Romantic Movies
# 3099  Action & Adventure, Comedies, International Mo...
# 3100                       Dramas, International Movies
# 3101    Comedies, International Movies, Romantic Movies
#
#                                             description
# 0     A woman adjusting to life after a loss contend...
# 1     Mourning the loss of their beloved junior high...
# 2     A family’s idyllic suburban life shatters when...
# 3     When an insatiable great white shark terrorize...
# 4     Four years after the last deadly shark attacks...
# ...                                                 ...
# 3097  Fed up with the uselessness of their degrees a...
# 3098  Finding a tantalizing clue in an old letter, a...
# 3099  When his girlfriend dumps him for being a bore...
# 3100  Three teenage misfits find camaraderie in sex,...
# 3101  A happy woman's new love is going great, but s...
#
# [3102 rows x 12 columns]

# %%
top_countries = grouped_df.nlargest(5, "count")

new_df = pd.DataFrame()

for ctry in top_countries['country']:
  mask = df['country'].str.contains(ctry)
  new_df = new_df.append(df[mask])

new_df.reset_index(drop = True, inplace = True)
new_df
# Out:
# <ipython-input-105-4595000a8bbe>:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append(df[mask])
# <ipython-input-105-4595000a8bbe>:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append(df[mask])
# <ipython-input-105-4595000a8bbe>:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append(df[mask])
# <ipython-input-105-4595000a8bbe>:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append(df[mask])
# <ipython-input-105-4595000a8bbe>:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append(df[mask])
#      show_id   type                title           director  \
# 0         s8  Movie              Sankofa       Haile Gerima
# 1        s10  Movie         The Starling     Theodore Melfi
# 2        s28  Movie            Grown Ups       Dennis Dugan
# 3        s29  Movie           Dark Skies      Scott Stewart
# 4        s30  Movie             Paranoia     Robert Luketic
# ...      ...    ...                  ...                ...
# 4493   s8652  Movie                Tyson       James Toback
# 4494   s8704  Movie  We Are Your Friends         Max Joseph
# 4495   s8716  Movie  Welcome to New York       Abel Ferrara
# 4496   s8777  Movie           Yellowbird  Christian De Vita
# 4497   s8795  Movie               اشتباك       Mohamed Diab
#
#                                                    cast  \
# 0     Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 1     Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 2     Adam Sandler, Kevin James, Chris Rock, David S...
# 3     Keri Russell, Josh Hamilton, J.K. Simmons, Dak...
# 4     Liam Hemsworth, Gary Oldman, Amber Heard, Harr...
# ...                                                 ...
# 4493                         Mike Tyson, Trevor Berbick
# 4494  Zac Efron, Wes Bentley, Emily Ratajkowski, Jon...
# 4495  Gérard Depardieu, Jacqueline Bisset, Marie Mou...
# 4496  Dakota Fanning, Seth Green, Christine Baranski...
# 4497  Nelly Karim, Hany Adel, Tarek Abdel Aziz, Ahme...
#
#                                                 country          date_added  \
# 0     United States, Ghana, Burkina Faso, United Kin...  September 24, 2021
# 1                                         United States  September 24, 2021
# 2                                         United States  September 20, 2021
# 3                                         United States  September 19, 2021
# 4                          United States, India, France  September 19, 2021
# ...                                                 ...                 ...
# 4493                              United States, France       March 1, 2019
# 4494              United Kingdom, France, United States    January 27, 2020
# 4495                              United States, France      March 23, 2017
# 4496                                    France, Belgium      August 5, 2015
# 4497                                      Egypt, France    October 11, 2018
#
#       release_year rating duration  \
# 0             1993  TV-MA  125 min
# 1             2021  PG-13  104 min
# 2             2010  PG-13  103 min
# 3             2013  PG-13   97 min
# 4             2013  PG-13  106 min
# ...            ...    ...      ...
# 4493          2008      R   90 min
# 4494          2015      R   96 min
# 4495          2014      R  108 min
# 4496          2014     PG   90 min
# 4497          2016  TV-14   98 min
#
#                                              listed_in  \
# 0     Dramas, Independent Movies, International Movies
# 1                                     Comedies, Dramas
# 2                                             Comedies
# 3                      Horror Movies, Sci-Fi & Fantasy
# 4                                            Thrillers
# ...                                                ...
# 4493                      Documentaries, Sports Movies
# 4494      Dramas, Independent Movies, Music & Musicals
# 4495                        Dramas, Independent Movies
# 4496                Children & Family Movies, Comedies
# 4497  Dramas, Independent Movies, International Movies
#
#                                             description
# 0     On a photo shoot in Ghana, an American model s...
# 1     A woman adjusting to life after a loss contend...
# 2     Mourning the loss of their beloved junior high...
# 3     A family’s idyllic suburban life shatters when...
# 4     Blackmailed by his company's CEO, a low-level ...
# ...                                                 ...
# 4493  In this surprisingly emotional documentary, he...
# 4494  An ambitious young DJ who knows how to work a ...
# 4495  A lecherous World Bank official sees his reput...
# 4496  An orphaned bird tags along with a flock on th...
# 4497  Amid the tumult following Egyptian President M...
#
# [4498 rows x 12 columns]

# %% [markdown]
# ## Task 2.3 - Chart

# %% [markdown]
# se the new dataframe to create a Pie Chart on the basis of number of Movies/TV Shows per country.

# %%
plt.pie(top['count'], labels = top['country'], autopct = '%1.2f%%')
plt.show()
